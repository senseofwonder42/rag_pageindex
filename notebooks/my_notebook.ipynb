# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ### Imports

# %%
# Import root to avoid relative imports in the notebook
from rag_pageindex.core.constants import (
    PROJECT_ROOT,
)

# Import functions or classes
from rag_pageindex.hello_world import (
    HelloWorld,
)

# %% [markdown]
# ### Code

# %%
HelloWorld.print_hello_world()

# %%
print(f"Project root path: {PROJECT_ROOT}")
